# %% [markdown]
# # Netflix Data Analysis Using Python
#
# ## Auspify Technologies Internship Project
#
# **Project:** Netflix Data Analysis
# **Tools Used:** Python, Pandas, Matplotlib, Jupyter Notebook
#
# ### Project Objective
# The objective of this project is to clean, analyze, and visualize the Netflix dataset to identify content distribution, country-wise patterns, and release year trends.

# %% [markdown]
# # TASK 1 - NETFLIX DATA CLEANING & PREPARATION

# %%
import pandas as pd

print("Pandas imported successfully!")
# Out:
# Pandas imported successfully!

# %%
df = pd.read_csv("Dataset.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   str
#  1   type          8790 non-null   str
#  2   title         8790 non-null   str
#  3   director      8790 non-null   str
#  4   country       8790 non-null   str
#  5   date_added    8790 non-null   str
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   str
#  8   duration      8790 non-null   str
#  9   listed_in     8790 non-null   str
# dtypes: int64(1), str(9)
# memory usage: 686.8 KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Records:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64
#
# Duplicate Records:
# 0

# %%
df[['type', 'country', 'rating']].head(10)
# Out:
#       type         country rating
# 0    Movie   United States  PG-13
# 1  TV Show          France  TV-MA
# 2  TV Show   United States  TV-MA
# 3    Movie          Brazil  TV-PG
# 4    Movie   United States  TV-MA
# 5  TV Show  United Kingdom  TV-14
# 6    Movie   United States  PG-13
# 7    Movie           India  TV-Y7
# 8    Movie         Germany  TV-MA
# 9    Movie           India  TV-Y7

# %%
df['type'] = df['type'].str.strip()
df['country'] = df['country'].str.strip()
df['rating'] = df['rating'].str.strip()

print("Columns standardized successfully!")
# Out:
# Columns standardized successfully!

# %%
df.to_csv("Netflix_Cleaned_Dataset.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!
